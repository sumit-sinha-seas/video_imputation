# %%
# %matplotlib inline
# !python /content/drive/MyDrive/Project/code/load_experiments.py --elbo SVGPVAE_Hensman --save --beta0 10 --m 15 --base_dir '/content/drive/MyDrive/Project/code/results/main_results_2_2/' --reload
# !python /content/drive/MyDrive/Project/code/load_experiments.py --elbo SVGPVAE_Hensman --save --beta0 1 --m 15 --base_dir '/content/drive/MyDrive/Project/code/results/main_results_2/' --reload
# !python /content/drive/MyDrive/Project/code/load_experiments.py --elbo SVGPVAE_Hensman --save --beta0 1 --m 10 --base_dir '/content/drive/MyDrive/Project/code/results/main_results_1/' --reload
# !python /content/drive/MyDrive/Project/code/load_experiments.py --elbo SVGPVAE_Hensman --save --beta0 1 --m 5 --base_dir '/content/drive/MyDrive/Project/code/results/main_results_0/' --reload
# Out:
# 2020-12-15 11:50:13.630883: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# True
#
# Checkpoint Directory:
# /content/drive/MyDrive/Project/code/results/main_results_2_2/
#
#
#
# Trainable variables:
# <tf.Variable 'encW:0' shape=(1024, 500) dtype=float32_ref>
# <tf.Variable 'encB:0' shape=(1, 500) dtype=float32_ref>
# <tf.Variable 'encW_1:0' shape=(500, 4) dtype=float32_ref>
# <tf.Variable 'encB_1:0' shape=(1, 4) dtype=float32_ref>
# <tf.Variable 'decW:0' shape=(2, 500) dtype=float32_ref>
# <tf.Variable 'decB:0' shape=(1, 500) dtype=float32_ref>
# ...

# %%
import os
os.makedirs('/content/drive/MyDrive/Project/code/debug/main_results_1/')
